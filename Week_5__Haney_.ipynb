# %% [markdown]
# <a href="https://colab.research.google.com/github/Redeemed-andWorthyKH/Biomed-DS/blob/main/Week_5__Haney_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Playing around in R
#install ggplot package

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
summary(diamonds)
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %%
colnames(diamonds)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"

# %%
mean(diamonds$price)
# Out:
# [1] 3932.8

# %%
price = diamonds$price
carat = diamonds$carat
cut = diamonds$cut
clarity = diamonds$clarity
depth = diamonds$depth
hist(price)
# Out:
# Plot with title “Histogram of price”

# %%
table(cut)
# Out:
# cut
#      Fair      Good Very Good   Premium     Ideal
#      1610      4906     12082     13791     21551

# %%
cor(price,carat)
# Out:
# [1] 0.9215913

# %%
cor.test(price,carat)
# Out:
# 	Pearson's product-moment correlation
#
# data:  price and carat
# t = 551.41, df = 53938, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.9203098 0.9228530
# sample estimates:
#       cor
# 0.9215913

# %%
hist(price[cut=="Ideal"])
# Out:
# Plot with title “Histogram of price[cut == "Ideal"]”

# %%
hist(price[cut=="Premium"])
# Out:
# Plot with title “Histogram of price[cut == "Premium"]”

# %%
t.test(price[cut=="Ideal"],price[cut=="Premium"])
# Out:
# 	Welch Two Sample t-test
#
# data:  price[cut == "Ideal"] and price[cut == "Premium"]
# t = -24.918, df = 26552, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1215.344 -1038.088
# sample estimates:
# mean of x mean of y
#  3457.542  4584.258

# %%
ggplot(diamonds, aes(x=carat, y=price, color=cut, shape=color)) + geom_point()
# Out:
# Warning message:
# “Using shapes for an ordinal variable is not advised”
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because more
# than 6 becomes difficult to discriminate
# ℹ you have requested 7 values. Consider specifying shapes manually if you need
#   that many of them.”
# Warning message:
# “Removed 2808 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price, color=cut, shape=clarity)) + geom_point()
# Out:
# Warning message:
# “Using shapes for an ordinal variable is not advised”
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because more
# than 6 becomes difficult to discriminate
# ℹ you have requested 8 values. Consider specifying shapes manually if you need
#   that many of them.”
# Warning message:
# “Removed 5445 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
