# %% [markdown]
# <a href="https://colab.research.google.com/github/Redeemed-andWorthyKH/Biomed-DS/blob/main/Week_1__MSBT__Haney.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5; b=10;
print(a+b)
# Out:
# 15

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

random_numbers = np.random.rand(100)
plt.hist(random_numbers)
plt.show()

df = pd.DataFrame(random_numbers)
df.head()

plt.title("Random Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.hist(df)
plt.show()

# %% [markdown]
# Welcome to my first coding assignment

# %%
plt.title("Random Numbers")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.hist(df)
plt.show()

# %%
num_sort = np.sort(random_numbers)
print(num_sort)
plt.plot(num_sort)
plt.show()
# Out:
# [3.18458390e-04 8.20790442e-03 9.79579302e-03 1.95162665e-02
#  3.56407642e-02 4.07511348e-02 4.33799617e-02 4.68475373e-02
#  6.58789248e-02 6.59450874e-02 8.04634560e-02 8.74247214e-02
#  9.39178691e-02 1.04040601e-01 1.12472521e-01 1.27318339e-01
#  1.38551709e-01 1.65931014e-01 1.76992340e-01 1.92058160e-01
#  1.99441342e-01 2.33346535e-01 2.33677890e-01 2.37200208e-01
#  2.48568158e-01 2.49178416e-01 2.52220100e-01 2.64633240e-01
#  2.65763609e-01 2.73579200e-01 2.81528504e-01 2.88456182e-01
#  2.94838553e-01 2.96370126e-01 3.03246586e-01 3.18523045e-01
#  3.45924753e-01 3.78006407e-01 3.78746404e-01 3.86104662e-01
#  3.89939082e-01 4.02837899e-01 4.21108797e-01 4.51471164e-01
#  4.59529094e-01 4.78390808e-01 4.81149332e-01 5.02934412e-01
#  5.06447843e-01 5.14138301e-01 5.15150240e-01 5.21670054e-01
#  5.32059661e-01 5.33760755e-01 5.34864043e-01 5.34904252e-01
#  5.54636655e-01 5.66849077e-01 5.69192577e-01 5.72350206e-01
# ...
